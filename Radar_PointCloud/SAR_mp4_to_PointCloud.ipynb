# %% [markdown]
# <a href="https://colab.research.google.com/github/Mmengyw/Capstone-Project/blob/main/Radar_PointCloud/SAR_mp4_to_PointCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import IPython
import matplotlib.pyplot as plt
from PIL import Image
from google.colab.patches import cv2_imshow
import numpy as np
from io import BytesIO


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Capstone/SAR_data"
# Out:
# camera30fps.mp4		 camera.mp4	      radar_sar.mp4
# camera_extrinsic.txt.pt  camera_times.pickle  sar_tracklog.pickle

# %%
RADAR_VIDEO = '/content/drive/My Drive/Capstone/SAR_data/radar_sar.mp4'
CAMERA_VIDEO = '/content/drive/My Drive/Capstone/SAR_data/camera.mp4'

# %%
def play_video(frame, index):
    """Inferences DeepLab model on a video file and stream the visualization."""
    original_im = Image.fromarray(frame[..., ::-1])
    plt.imshow(original_im)
    return

# %%
def getGrayArray(frame):
  gray_frame = 255 - cv.cvtColor(frame,cv.COLOR_RGB2GRAY)
  gray_values = np.zeros(gray_frame.shape)
  plt.imshow(gray_values)

  return gray_values

# %%
frames=[]
video_radar = cv.VideoCapture(RADAR_VIDEO)
num_frames = 50 


A = np.zeros((num_frames,624,1250))

try:
    for i in range(num_frames):
        _, frame = video_radar.read()
        if not _: break
        # play_video(frame, i)
        A[i] = getGrayArray(frame)
        IPython.display.clear_output(wait=True)
except KeyboardInterrupt:
    plt.close()
    print("Stream stopped.")

# video_radar.get(cv.CAP_PROP_POS_MSEC)


# print(len(frame[0][0]))

# fourcc = cv.VideoWriter_fourcc(*'MJPG')
# out = cv.VideoWriter('3D_pointcloud.avi', fourcc, 20.0, size)
 
# for i in range(len(frames)):
#     out.write(frames[i])
# out.release()

# %%
# import torch
# torch.load('/content/drive/My Drive/Capstone/SAR_data/camera_extrinsic.txt.pt')

# %%
gray_frame = 255 - cv.cvtColor(frame,cv.COLOR_RGB2GRAY)

gray_frame = (gray_frame>220)*gray_frame


cv2_imshow(gray_frame)
# Out:
# <PIL.Image.Image image mode=L size=1250x624 at 0x7F71DA178A50>
